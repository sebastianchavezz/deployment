# %%
from flask import Flask, app, request, render_template, redirect,url_for, jsonify
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, Float, String, MetaData, Boolean
import pandas as pd

from sqlalchemy.orm import declarative_base, sessionmaker
import sqlalchemy

# %%
Base = declarative_base()

# %%
engine = create_engine('sqlite:///database2.db',echo=False)
conn = engine.connect()

# %%
df= pd.read_csv('final_database.csv')
df
# Out:
#       Unnamed: 0                                         name  steam_id  \
# 0        1172620                               Sea of Thieves   1172620
# 1         489830  The Elder Scrolls V: Skyrim Special Edition    489830
# 2        1172380                STAR WARS Jedi: Fallen Order™   1172380
# 3         433850                             Z1 Battle Royale    433850
# 4         433340                                Slime Rancher    433340
# ...          ...                                          ...       ...
# 4620     1197360                          The Santa Challenge   1197360
# 4621      496320                                 Running Gods    496320
# 4622      495030                               VR Battle Grid    495030
# 4623     1196350                             ATROFIL: THE KEY   1196350
# 4624     1170170                   Alfonzo's Arctic Adventure   1170170
#
#                    developers  reviews  positives  is_free  units_sold  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'steam_id', 'developers', 'reviews', 'positives',
#        'is_free', 'units_sold', 'prices_eu', 'final_revenue', 'genre'],
#       dtype='object')

# %%
df = df.rename(columns={'Unnamed: 0':'index'})

# %%
df
# Out:
#         index                                         name  steam_id  \
# 0     1172620                               Sea of Thieves   1172620
# 1      489830  The Elder Scrolls V: Skyrim Special Edition    489830
# 2     1172380                STAR WARS Jedi: Fallen Order™   1172380
# 3      433850                             Z1 Battle Royale    433850
# 4      433340                                Slime Rancher    433340
# ...       ...                                          ...       ...
# 4620  1197360                          The Santa Challenge   1197360
# 4621   496320                                 Running Gods    496320
# 4622   495030                               VR Battle Grid    495030
# 4623  1196350                             ATROFIL: THE KEY   1196350
# 4624  1170170                   Alfonzo's Arctic Adventure   1170170
#
#                    developers  reviews  positives  is_free  units_sold  \
# ...

# %%
df.to_sql(name='games',con=engine,index=False,if_exists='replace')

# %%
meta = MetaData()
meta.create_all(engine)
